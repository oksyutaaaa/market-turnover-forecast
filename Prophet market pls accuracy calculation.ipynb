# %% [markdown]
# Імпорт бібліотек

# %%
import pandas as pd
import numpy as np
from prophet import Prophet
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# Підготовка даних

# %%
df = pd.read_csv("forecast_of_market_dataset.csv")

df['month'] = pd.to_datetime(df['month'], errors='coerce')

eval_period = (df['month'] >= '2024-01-01') & (df['month'] <= '2024-12-31')
test_df = df[eval_period].copy()

train_df = df[df['month'] < '2024-01-01'].copy()

forecast_dates = pd.date_range('2024-01-01', '2024-12-01', freq='MS')

# %% [markdown]
# Запуск моделі

# %%
product_groups = train_df['product_group_id'].unique()
results = []

for group_id in tqdm(product_groups, desc="Forecasting per product group"):
    group_train = train_df[train_df['product_group_id'] == group_id]

    # Loop over both targets
    for target_col in ['market_revenue', 'revenue_amazon']:
        series = group_train[['month', target_col]].dropna()
        series = series.rename(columns={'month': 'ds', target_col: 'y'})

        if len(series) < 12 or series['y'].nunique() <= 1:
            continue  # Skip sparse or flat series

        model = Prophet()
        try:
            model.fit(series)
            future = pd.DataFrame({'ds': forecast_dates})
            forecast = model.predict(future)[['ds', 'yhat']]

            # Add metadata
            forecast['product_group_id'] = group_id
            forecast['target'] = target_col
            results.append(forecast)
        except Exception as e:
            print(f"⚠️ Skipped {target_col} for group {group_id}: {e}")
            continue
# Out:
# Forecasting per product group:   0%|          | 0/29 [00:00<?, ?it/s]22:51:25 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:26 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:26 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:26 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:   3%|▎         | 1/29 [00:01<00:32,  1.17s/it]22:51:26 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:27 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:27 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:27 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:   7%|▋         | 2/29 [00:01<00:25,  1.07it/s]22:51:27 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:27 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:28 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:28 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  10%|█         | 3/29 [00:02<00:24,  1.05it/s]22:51:28 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:29 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:29 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:29 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  14%|█▍        | 4/29 [00:03<00:23,  1.07it/s]22:51:29 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:29 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:30 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:30 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  17%|█▋        | 5/29 [00:04<00:22,  1.07it/s]22:51:30 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:30 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:31 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:31 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  21%|██        | 6/29 [00:05<00:21,  1.07it/s]22:51:31 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:31 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  24%|██▍       | 7/29 [00:06<00:16,  1.31it/s]22:51:31 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:32 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:32 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:32 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  28%|██▊       | 8/29 [00:07<00:17,  1.21it/s]22:51:32 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:33 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:33 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:33 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  31%|███       | 9/29 [00:07<00:17,  1.16it/s]22:51:33 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:33 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:34 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:34 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  34%|███▍      | 10/29 [00:08<00:16,  1.13it/s]22:51:34 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:35 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  38%|███▊      | 11/29 [00:09<00:14,  1.21it/s]22:51:35 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:35 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:35 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:36 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  41%|████▏     | 12/29 [00:10<00:14,  1.14it/s]22:51:36 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:36 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:36 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:37 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  45%|████▍     | 13/29 [00:11<00:14,  1.10it/s]22:51:37 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:37 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:37 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:38 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  48%|████▊     | 14/29 [00:12<00:14,  1.03it/s]22:51:38 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:38 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:39 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:39 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  52%|█████▏    | 15/29 [00:13<00:14,  1.06s/it]22:51:39 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:40 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:40 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:40 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  55%|█████▌    | 16/29 [00:15<00:14,  1.09s/it]22:51:40 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:41 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:41 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:41 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  59%|█████▊    | 17/29 [00:16<00:13,  1.12s/it]22:51:42 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:42 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  62%|██████▏   | 18/29 [00:16<00:10,  1.09it/s]22:51:42 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:42 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:42 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:43 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  66%|██████▌   | 19/29 [00:17<00:08,  1.13it/s]22:51:43 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:43 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:44 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:44 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  69%|██████▉   | 20/29 [00:18<00:09,  1.01s/it]22:51:44 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:44 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:45 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:46 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  72%|███████▏  | 21/29 [00:20<00:09,  1.18s/it]22:51:46 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:46 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  76%|███████▌  | 22/29 [00:20<00:06,  1.02it/s]22:51:46 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:47 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  79%|███████▉  | 23/29 [00:21<00:05,  1.17it/s]22:51:47 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:47 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  83%|████████▎ | 24/29 [00:21<00:03,  1.38it/s]22:51:47 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:48 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  86%|████████▌ | 25/29 [00:22<00:02,  1.45it/s]22:51:48 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:48 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:48 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:49 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  90%|████████▉ | 26/29 [00:23<00:02,  1.31it/s]22:51:49 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:49 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:49 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:50 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  93%|█████████▎| 27/29 [00:24<00:01,  1.15it/s]22:51:50 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:50 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:50 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:51 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group:  97%|█████████▋| 28/29 [00:25<00:00,  1.15it/s]22:51:51 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:51 - cmdstanpy - INFO - Chain [1] done processing
# 22:51:51 - cmdstanpy - INFO - Chain [1] start processing
# 22:51:52 - cmdstanpy - INFO - Chain [1] done processing
# Forecasting per product group: 100%|██████████| 29/29 [00:26<00:00,  1.10it/s]

# %% [markdown]
# Об'єднання результатів прогнозу з фактом

# %%
forecast_df = pd.concat(results, ignore_index=True)
actual_df = test_df.melt(
    id_vars=['month', 'product_group_id'],
    value_vars=['market_revenue', 'revenue_amazon'],
    var_name='target',
    value_name='actual'
).rename(columns={'month': 'ds'})

results_merged = pd.merge(forecast_df, actual_df, on=['product_group_id', 'ds', 'target'], how='inner')

# %% [markdown]
# Розрахунок метрик

# %%
results_merged['abs_error'] = (results_merged['actual'] - results_merged['yhat']).abs()
results_merged['pct_error'] = results_merged['abs_error'] / results_merged['actual'].replace(0, np.nan)
results_merged['weighted_error'] = results_merged['abs_error'] * results_merged['actual']

results_clean = results_merged.dropna(subset=['actual', 'yhat'])

# %% [markdown]
# Відображення результатів

# %%
metrics = results_clean.groupby('target').agg(
    MAE=('abs_error', 'mean'),
    MAPE=('pct_error', lambda x: np.mean(x.dropna()) * 100)
).reset_index()

wmape_df = results_clean.groupby('target').apply(
    lambda g: (g['weighted_error'].sum() / g['actual'].sum()) * 100
).reset_index().rename(columns={0: 'WMAPE'})

metrics = pd.merge(metrics, wmape_df, on='target')


print(metrics)
# Out:
#            target           MAE       MAPE         WMAPE
# 0  market_revenue  8.736675e+08  20.923066  2.798600e+11
# 1  revenue_amazon  9.531871e+07  20.689680  2.488396e+10
# C:\Users\Admin\AppData\Local\Temp\ipykernel_29076\3305834209.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   wmape_df = results_clean.groupby('target').apply(

# %%
plot_df = results_clean.groupby(['ds', 'target']).agg({
    'actual': 'sum',
    'yhat': 'sum'
}).reset_index()

plt.figure(figsize=(14, 6))
for target in plot_df['target'].unique():
    subset = plot_df[plot_df['target'] == target]
    plt.plot(subset['ds'], subset['actual'], marker='o', label=f"{target} (Actual)")
    plt.plot(subset['ds'], subset['yhat'], marker='x', linestyle='--', label=f"{target} (Forecast)")

plt.title("📉 Actual vs Forecasted Revenue (2024)")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_29076\3425019517.py:18: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
